# %% [markdown]
# <a href="https://colab.research.google.com/github/Kdavis2025/stamp-prices-/blob/main/stamp_prices_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plot US Stamp Prices Over Time

# %%
# Import the libraries that we need
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# This dataset is from: https://vincentarelbundock.github.io/Rdatasets/datasets.html

# %%
# pd.read_csv will turn a csv file into a pandas dataframe
stamp_prices = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/USstamps.csv')

# type() will return the type of an object. This identifies that stamp_prices is a dataframe
type(stamp_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
#head() will retun the ecolumn names and the first few rows from the data frame
stamp_prices.head()
# Out:
#    rownames  Year  Price
# 0         1  1885      2
# 1         2  1917      3
# 2         3  1919      2
# 3         4  1932      3
# 4         5  1958      4

# %%
# Plot year vs price (x vs y)
# Step 1: set the plot title
plt.title('Stamp Prices Over Time In The US')

# Step 2: set the columns to be plotted
plt.scatter(stamp_prices['Year'],stamp_prices['Price'])
